# %% [markdown]
# <a href="https://colab.research.google.com/github/emngarcia/TikTokViralSongs/blob/main/cluster_creation_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# reading in df with lyrics and audio features
import pandas as pd

df = pd.read_csv('merged_right.csv')

# dropping duplicate rows (songs popular multiple years) for clustering
df.drop(columns=['Unnamed: 0'], inplace=True)
df.drop_duplicates(inplace = True, subset = ['lyrics'], keep = 'first')

df
# Out:
#                         track_name                 artist_name  artist_pop  \
# 0                         Shake It               Metro Station          53
# 1                 Chinese New Year                       SALES          61
# 3                   Baby I'm Yours                    Breakbot          57
# 6                       The Git Up                Blanco Brown          60
# 8             Say Hey (I Love You)  Michael Franti & Spearhead          58
# ..                             ...                         ...         ...
# 839            California Dreaming                        Jorm          42
# 840                       Rockstar                Ilkay Sencan          61
# 841                         Lovely                      Alfons          58
# 842  Jimmy Cooks (feat. 21 Savage)                       Drake          95
# 843                   Good Looking             Suki Waterhouse          64
#
#                    album  track_pop  danceability  energy  loudness  mode  \
# 0          Metro Station         68         0.618   0.955    -3.836     1
# 1             SALES - EP         53         0.744   0.845    -7.422     0
# 3           By Your Side         69         0.829   0.792    -3.755     0
# 6             The Git Up          2         0.847   0.678    -8.635     1
# 8      All Rebel Rockers          0         0.738   0.983    -4.374     0
# ..                   ...        ...           ...     ...       ...   ...
# 839  California Dreaming         53         0.717   0.865    -4.126     0
# 840             Rockstar         69         0.771   0.826    -3.978     1
# 841               Lovely         45         0.504   0.677    -6.954     0
# 842  Honestly, Nevermind         92         0.529   0.673    -4.711     1
# 843         Good Looking         80         0.377   0.558    -9.076     1
#
#      key  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0      4       0.0798      0.002210          0.000003     0.486   0.7900
# 1      4       0.2530      0.759000          0.232000     0.100   0.7490
# 3      2       0.0668      0.726000          0.000006     0.122   0.7580
# 6      9       0.1090      0.066900          0.000000     0.274   0.8110
# 8      5       0.0855      0.038000          0.000006     0.183   0.9570
# ..   ...          ...           ...               ...       ...      ...
# 839    1       0.0307      0.022200          0.001200     0.605   0.4870
# 840   11       0.0604      0.142000          0.030000     0.145   0.1850
# 841    4       0.0640      0.316000          0.001270     0.268   0.0375
# 842    0       0.1750      0.000307          0.000002     0.093   0.3660
# 843    4       0.0299      0.078900          0.000342     0.125   0.2670
#
#        tempo  time_signature  duration_ms  year  \
# 0    150.034               4       179947  2019
# 1     75.221               4       160000  2019
# 3    118.050               4       215507  2019
# 6     97.984               4       200594  2019
# 8     92.998               4       235760  2019
# ..       ...             ...          ...   ...
# 839  124.048               4       152323  2022
# 840  100.012               4       212280  2022
# 841  128.078               4       159023  2022
# 842  165.921               4       218365  2022
# 843  149.971               3       214800  2022
#
#                                                 lyrics
# 0    Let’s drop!\nYeah, come on\nShake, shake\n\nI'...
# 1    I'll see you at the movies\nI see you with you...
# 3    I thought I had it all together\nBut I was led...
# 6    Right now\nI just need you to get real loose\n...
# 8    Comme da selecta\nAyy, uh-huh, woo (That's rig...
# ..                                                 ...
# 839  All the leaves are brown\nAnd the sky is grey\...
# 840  I've been fuckin' hoes and poppin' pillies\nMa...
# 841  Одинокий прекрасный\nВ синем небе парил\nПрола...
# 842  Вновь проснулся бодреньким, так что знай: я в ...
# 843  Tides thrash inside, baby, I'm high octane\nFe...
#
# [700 rows x 20 columns]

# %%
# df.to_csv('merged_right_nodupes.csv')

# %%
# k means clustering with lyrics and audio features
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline

transformer = make_column_transformer(
    (StandardScaler(), ['key', 'mode', 'valence', 'tempo', 'time_signature', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness']),
    (TfidfVectorizer(max_features = 1000), 'lyrics')
)

model = KMeans(n_clusters=5)

pipeline = Pipeline([
    ('transform', transformer),
    ('cluster', model)
])


pipeline.fit(df)
# Out:
# Pipeline(steps=[('transform',
#                  ColumnTransformer(transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   ['key', 'mode', 'valence',
#                                                    'tempo', 'time_signature',
#                                                    'danceability', 'energy',
#                                                    'loudness', 'speechiness',
#                                                    'acousticness',
#                                                    'instrumentalness',
#                                                    'liveness']),
#                                                  ('tfidfvectorizer',
#                                                   TfidfVectorizer(max_features=1000),
#                                                   'lyrics')])),
#                 ('cluster', KMeans(n_clusters=5))])

# %%
centroids = model.cluster_centers_
clusters = model.labels_

df["Cluster"] = clusters

# printing artists in each cluster
for cluster_id in range(model.n_clusters):
  print(cluster_id)
  print(df[df["Cluster"] == cluster_id]["artist_name"])
# Out:
# 0
# 0           Metro Station
# 6            Blanco Brown
# 11            Bag Raiders
# 15               Ashley O
# 16     Falling In Reverse
#               ...
# 832             Dame Dame
# 834                DaBaby
# 836                   CPX
# 840          Ilkay Sencan
# 842                 Drake
# Name: artist_name, Length: 225, dtype: object
# 1
# 21          Andrew Gold
# 25            Flo Milli
# 29           KRYPTO9095
# 30     Supa Dupa Humble
# 36         Ant Saunders
#              ...
# 808       The Kid LAROI
# 818    Young T & Bugsey
# 835          DripReport
# 837              Halsey
# 838        Rich The Kid
# Name: artist_name, Length: 144, dtype: object
# 2
# 3                        Breakbot
# 8      Michael Franti & Spearhead
# 18                         WILLOW
# 23                   Selena Gomez
# 31                   Tierra Whack
#                   ...
# 822                        Coopex
# 830                     Dame Dame
# 831                    The Weeknd
# 833                  Lil Uzi Vert
# 839                          Jorm
# Name: artist_name, Length: 161, dtype: object
# 3
# 1           SALES
# 9         Peachy!
# 13          Sueco
# 28            SIX
# 33          Swell
#           ...
# 815         Quavo
# 817           CPX
# 819    THE SCOTTS
# 829        Future
# 841        Alfons
# Name: artist_name, Length: 117, dtype: object
# 4
# 17                   Bill Wurtz
# 22                     Tiny Tim
# 46                    Paul Anka
# 53                 Jack Stauber
# 58                     ilyTOMMY
# 97                  girl in red
# 102                Current Joys
# 122             Gaten Matarazzo
# 132           Rex Orange County
# 144                Neil Diamond
# 189                Patrick Page
# 191                        Roar
# 207                     JP Saxe
# 208                  The Champs
# 215                       dodie
# 217             Christina Perri
# 227                       Limbo
# 230                   blackbear
# 271                        Ashe
# 279               Ariana Grande
# 282                Madison Beer
# 324                  Thundercat
# 336                  Conan Gray
# 342                        Joji
# 362                      Boxout
# 369    Electric Light Orchestra
# 403              Olivia Rodrigo
# 440                 Kaash Paige
# 461                     Rihanna
# 470                        Xilo
# 479                  Ark Patrol
# 482                    Labrinth
# 492                   Lyn Lapid
# 498                        Joji
# 503                       Cults
# 534                     Sezairi
# 536                Madison Beer
# 537              Olivia Rodrigo
# 554                       dhruv
# 587                      Giveon
# 598              Olivia Rodrigo
# 600              Olivia Rodrigo
# 661                 Luke Chiang
# 671                    RealestK
# 703                         Sia
# 717                  Elley Duhé
# 730                        Joji
# 741             Stephen Sanchez
# 761                       SALES
# 778                  Surf Curse
# 789                   VANO 3000
# 799                     Kauai45
# 843             Suki Waterhouse
# Name: artist_name, dtype: object

# %%
# printing songs in each cluster
for cluster_id in range(model.n_clusters):
  print(cluster_id)
  print(df[df["Cluster"] == cluster_id]["track_name"])
# Out:
# 0
# 0                           Shake It
# 6                         The Git Up
# 11                    Shooting Stars
# 15                         On A Roll
# 16               Good Girls Bad Guys
#                    ...
# 832                        Let It Go
# 834                              BOP
# 836                           Demons
# 840                         Rockstar
# 842    Jimmy Cooks (feat. 21 Savage)
# Name: track_name, Length: 225, dtype: object
# 1
# 21           Spooky, Scary Skeletons
# 25                       Beef FloMix
# 29            Woah (feat. D3Mstreet)
# 30                          Steppin'
# 36                     Yellow Hearts
#                    ...
# 808                      WITHOUT YOU
# 818    Don't Rush (feat. Headie One)
# 835                         Skechers
# 837                       Without Me
# 838                        Plug Walk
# Name: track_name, Length: 144, dtype: object
# 2
# 3                                   Baby I'm Yours
# 8                             Say Hey (I Love You)
# 18                                  Wait a Minute!
# 23     Tell Me Something I Don't Know - Soundtrack
# 31                                    Hungry Hippo
#                           ...
# 822                                      Only Girl
# 830                                         DÁKITI
# 831                                   In Your Eyes
# 833                                       That Way
# 839                            California Dreaming
# Name: track_name, Length: 161, dtype: object
# 3
# 1                   Chinese New Year
# 9                      Falling for U
# 13                              fast
# 28                Don't Lose Ur Head
# 33                         I'm Sorry
#                    ...
# 815    FLIP THE SWITCH (feat. Drake)
# 817                    Love Me Again
# 819                       THE SCOTTS
# 829       Life Is Good (feat. Drake)
# 841                           Lovely
# Name: track_name, Length: 117, dtype: object
# 4
# 17                                 Just Did a Bad Thing
# 22     Livin' in the Sunlight, Lovin' in the Moon Light
# 46                         Put Your Head on My Shoulder
# 53                                            Buttercup
# 58                                       Tunnel of Love
# 97                           we fell in love in october
# 102                                           New Flesh
# 122                                  Never Ending Story
# 132                                     Corduroy Dreams
# 144                                      Sweet Caroline
# 189                                           Out There
# 191                               I Can't Handle Change
# 207      If the World Was Ending (feat. Julia Michaels)
# 208                                             Tequila
# 215               Not What I Meant (feat. Lewis Watson)
# 217                                    A Thousand Years
# 227                                       Airplane Mode
# 230                                     hot girl bummer
# 271                                  Moral of the Story
# 279                   Stuck with U (with Justin Bieber)
# 282                                             Selfish
# 324                                         Funny Thing
# 336                                             Heather
# 342                                          Gimme Love
# 362                  I Just Want to Be the One You Love
# 369                                        Mr. Blue Sky
# 403                                          All I Want
# 440                                          Love Songs
# 461                                           Desperado
# 470                                           Aesthetic
# 479                                              Let Go
# 482                            Still Don't Know My Name
# 492                                   When She Loved Me
# 498                            SLOW DANCING IN THE DARK
# 503                                      Always Forever
# 534                                            It's You
# 536                                            Reckless
# 537                                             deja vu
# 554                                         double take
# 587                              Heartbreak Anniversary
# 598                                     drivers license
# 600                                             happier
# 661                                        Shouldn't Be
# 671                                                 WFM
# 703                                             Snowman
# 717                                 MIDDLE OF THE NIGHT
# 730                                       Glimpse of Us
# 741                                   Until I Found You
# 761                                  Pope Is a Rockstar
# 778                                              Freaks
# 789                                        Running Away
# 799                                  Just The Two of Us
# 843                                        Good Looking
# Name: track_name, dtype: object

# %%
# df.to_csv('merged_right_nodupes_clusters.csv')

# %%
# loading in df with duplicates
df_dupes = pd.read_csv('merged_right.csv')
df_dupes.drop(columns=['Unnamed: 0'], inplace=True)

df_dupes
# Out:
#                         track_name      artist_name  artist_pop  \
# 0                         Shake It    Metro Station          53
# 1                 Chinese New Year            SALES          61
# 2                 Chinese New Year            SALES          61
# 3                   Baby I'm Yours         Breakbot          57
# 4                   Baby I'm Yours         Breakbot          57
# ..                             ...              ...         ...
# 839            California Dreaming             Jorm          42
# 840                       Rockstar     Ilkay Sencan          61
# 841                         Lovely           Alfons          58
# 842  Jimmy Cooks (feat. 21 Savage)            Drake          95
# 843                   Good Looking  Suki Waterhouse          64
#
#                    album  track_pop  danceability  energy  loudness  mode  \
# 0          Metro Station         68         0.618   0.955    -3.836     1
# 1             SALES - EP         53         0.744   0.845    -7.422     0
# 2       Chinese New Year         66         0.744   0.845    -7.422     0
# 3           By Your Side         69         0.829   0.792    -3.755     0
# 4           By Your Side         69         0.829   0.792    -3.755     0
# ..                   ...        ...           ...     ...       ...   ...
# 839  California Dreaming         53         0.717   0.865    -4.126     0
# 840             Rockstar         69         0.771   0.826    -3.978     1
# 841               Lovely         45         0.504   0.677    -6.954     0
# 842  Honestly, Nevermind         92         0.529   0.673    -4.711     1
# 843         Good Looking         80         0.377   0.558    -9.076     1
#
#      key  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0      4       0.0798      0.002210          0.000003     0.486   0.7900
# 1      4       0.2530      0.759000          0.232000     0.100   0.7490
# 2      4       0.2530      0.759000          0.232000     0.100   0.7490
# 3      2       0.0668      0.726000          0.000006     0.122   0.7580
# 4      2       0.0668      0.726000          0.000006     0.122   0.7580
# ..   ...          ...           ...               ...       ...      ...
# 839    1       0.0307      0.022200          0.001200     0.605   0.4870
# 840   11       0.0604      0.142000          0.030000     0.145   0.1850
# 841    4       0.0640      0.316000          0.001270     0.268   0.0375
# 842    0       0.1750      0.000307          0.000002     0.093   0.3660
# 843    4       0.0299      0.078900          0.000342     0.125   0.2670
#
#        tempo  time_signature  duration_ms  year  \
# 0    150.034               4       179947  2019
# 1     75.221               4       160000  2019
# 2     75.221               4       160000  2020
# 3    118.050               4       215507  2019
# 4    118.050               4       215507  2020
# ..       ...             ...          ...   ...
# 839  124.048               4       152323  2022
# 840  100.012               4       212280  2022
# 841  128.078               4       159023  2022
# 842  165.921               4       218365  2022
# 843  149.971               3       214800  2022
#
#                                                 lyrics
# 0    Let’s drop!\nYeah, come on\nShake, shake\n\nI'...
# 1    I'll see you at the movies\nI see you with you...
# 2    I'll see you at the movies\nI see you with you...
# 3    I thought I had it all together\nBut I was led...
# 4    I thought I had it all together\nBut I was led...
# ..                                                 ...
# 839  All the leaves are brown\nAnd the sky is grey\...
# 840  I've been fuckin' hoes and poppin' pillies\nMa...
# 841  Одинокий прекрасный\nВ синем небе парил\nПрола...
# 842  Вновь проснулся бодреньким, так что знай: я в ...
# 843  Tides thrash inside, baby, I'm high octane\nFe...
#
# [844 rows x 20 columns]

# %%
# subset of df with clusters, track, artist
df_cluster = df[['track_name', 'artist_name', 'Cluster']]
df_cluster
# Out:
#                         track_name                 artist_name  Cluster
# 0                         Shake It               Metro Station        0
# 1                 Chinese New Year                       SALES        3
# 3                   Baby I'm Yours                    Breakbot        2
# 6                       The Git Up                Blanco Brown        0
# 8             Say Hey (I Love You)  Michael Franti & Spearhead        2
# ..                             ...                         ...      ...
# 839            California Dreaming                        Jorm        2
# 840                       Rockstar                Ilkay Sencan        0
# 841                         Lovely                      Alfons        3
# 842  Jimmy Cooks (feat. 21 Savage)                       Drake        0
# 843                   Good Looking             Suki Waterhouse        4
#
# [700 rows x 3 columns]

# %%
# merging cluster df to add clusters all songs including duplicates with a different year
df_dupes_cluster = df_dupes.merge(df_cluster, on = ['track_name', 'artist_name'], how = 'left')

df_dupes_cluster
# Out:
#                         track_name      artist_name  artist_pop  \
# 0                         Shake It    Metro Station          53
# 1                 Chinese New Year            SALES          61
# 2                 Chinese New Year            SALES          61
# 3                   Baby I'm Yours         Breakbot          57
# 4                   Baby I'm Yours         Breakbot          57
# ..                             ...              ...         ...
# 839            California Dreaming             Jorm          42
# 840                       Rockstar     Ilkay Sencan          61
# 841                         Lovely           Alfons          58
# 842  Jimmy Cooks (feat. 21 Savage)            Drake          95
# 843                   Good Looking  Suki Waterhouse          64
#
#                    album  track_pop  danceability  energy  loudness  mode  \
# 0          Metro Station         68         0.618   0.955    -3.836     1
# 1             SALES - EP         53         0.744   0.845    -7.422     0
# 2       Chinese New Year         66         0.744   0.845    -7.422     0
# 3           By Your Side         69         0.829   0.792    -3.755     0
# 4           By Your Side         69         0.829   0.792    -3.755     0
# ..                   ...        ...           ...     ...       ...   ...
# 839  California Dreaming         53         0.717   0.865    -4.126     0
# 840             Rockstar         69         0.771   0.826    -3.978     1
# 841               Lovely         45         0.504   0.677    -6.954     0
# 842  Honestly, Nevermind         92         0.529   0.673    -4.711     1
# 843         Good Looking         80         0.377   0.558    -9.076     1
#
#      key  ...  acousticness  instrumentalness  liveness  valence    tempo  \
# 0      4  ...      0.002210          0.000003     0.486   0.7900  150.034
# 1      4  ...      0.759000          0.232000     0.100   0.7490   75.221
# 2      4  ...      0.759000          0.232000     0.100   0.7490   75.221
# 3      2  ...      0.726000          0.000006     0.122   0.7580  118.050
# 4      2  ...      0.726000          0.000006     0.122   0.7580  118.050
# ..   ...  ...           ...               ...       ...      ...      ...
# 839    1  ...      0.022200          0.001200     0.605   0.4870  124.048
# 840   11  ...      0.142000          0.030000     0.145   0.1850  100.012
# 841    4  ...      0.316000          0.001270     0.268   0.0375  128.078
# 842    0  ...      0.000307          0.000002     0.093   0.3660  165.921
# 843    4  ...      0.078900          0.000342     0.125   0.2670  149.971
#
#      time_signature  duration_ms  year  \
# 0                 4       179947  2019
# 1                 4       160000  2019
# 2                 4       160000  2020
# 3                 4       215507  2019
# 4                 4       215507  2020
# ..              ...          ...   ...
# 839               4       152323  2022
# 840               4       212280  2022
# 841               4       159023  2022
# 842               4       218365  2022
# 843               3       214800  2022
#
#                                                 lyrics Cluster
# 0    Let’s drop!\nYeah, come on\nShake, shake\n\nI'...     0.0
# 1    I'll see you at the movies\nI see you with you...     3.0
# 2    I'll see you at the movies\nI see you with you...     3.0
# 3    I thought I had it all together\nBut I was led...     2.0
# 4    I thought I had it all together\nBut I was led...     2.0
# ..                                                 ...     ...
# 839  All the leaves are brown\nAnd the sky is grey\...     2.0
# 840  I've been fuckin' hoes and poppin' pillies\nMa...     0.0
# 841  Одинокий прекрасный\nВ синем небе парил\nПрола...     3.0
# 842  Вновь проснулся бодреньким, так что знай: я в ...     0.0
# 843  Tides thrash inside, baby, I'm high octane\nFe...     4.0
#
# [844 rows x 21 columns]

# %%
# df_dupes_cluster.to_csv('merged_right_withdupes_clusters.csv')

# %%
# reading in df with clusters and no duplicates
df = pd.read_csv('merged_right_nodupes_clusters.csv')

df.drop(columns=['Unnamed: 0'], inplace=True)

df
# Out:
#                         track_name                 artist_name  artist_pop  \
# 0                         Shake It               Metro Station          53
# 1                 Chinese New Year                       SALES          61
# 2                   Baby I'm Yours                    Breakbot          57
# 3                       The Git Up                Blanco Brown          60
# 4             Say Hey (I Love You)  Michael Franti & Spearhead          58
# ..                             ...                         ...         ...
# 695            California Dreaming                        Jorm          42
# 696                       Rockstar                Ilkay Sencan          61
# 697                         Lovely                      Alfons          58
# 698  Jimmy Cooks (feat. 21 Savage)                       Drake          95
# 699                   Good Looking             Suki Waterhouse          64
#
#                    album  track_pop  danceability  energy  loudness  mode  \
# 0          Metro Station         68         0.618   0.955    -3.836     1
# 1             SALES - EP         53         0.744   0.845    -7.422     0
# 2           By Your Side         69         0.829   0.792    -3.755     0
# 3             The Git Up          2         0.847   0.678    -8.635     1
# 4      All Rebel Rockers          0         0.738   0.983    -4.374     0
# ..                   ...        ...           ...     ...       ...   ...
# 695  California Dreaming         53         0.717   0.865    -4.126     0
# 696             Rockstar         69         0.771   0.826    -3.978     1
# 697               Lovely         45         0.504   0.677    -6.954     0
# 698  Honestly, Nevermind         92         0.529   0.673    -4.711     1
# 699         Good Looking         80         0.377   0.558    -9.076     1
#
#      key  ...  acousticness  instrumentalness  liveness  valence    tempo  \
# 0      4  ...      0.002210          0.000003     0.486   0.7900  150.034
# 1      4  ...      0.759000          0.232000     0.100   0.7490   75.221
# 2      2  ...      0.726000          0.000006     0.122   0.7580  118.050
# 3      9  ...      0.066900          0.000000     0.274   0.8110   97.984
# 4      5  ...      0.038000          0.000006     0.183   0.9570   92.998
# ..   ...  ...           ...               ...       ...      ...      ...
# 695    1  ...      0.022200          0.001200     0.605   0.4870  124.048
# 696   11  ...      0.142000          0.030000     0.145   0.1850  100.012
# 697    4  ...      0.316000          0.001270     0.268   0.0375  128.078
# 698    0  ...      0.000307          0.000002     0.093   0.3660  165.921
# 699    4  ...      0.078900          0.000342     0.125   0.2670  149.971
#
#      time_signature  duration_ms  year  \
# 0                 4       179947  2019
# 1                 4       160000  2019
# 2                 4       215507  2019
# 3                 4       200594  2019
# 4                 4       235760  2019
# ..              ...          ...   ...
# 695               4       152323  2022
# 696               4       212280  2022
# 697               4       159023  2022
# 698               4       218365  2022
# 699               3       214800  2022
#
#                                                 lyrics Cluster
# 0    Let’s drop!\nYeah, come on\nShake, shake\n\nI'...       0
# 1    I'll see you at the movies\nI see you with you...       2
# 2    I thought I had it all together\nBut I was led...       2
# 3    Right now\nI just need you to get real loose\n...       0
# 4    Comme da selecta\nAyy, uh-huh, woo (That's rig...       2
# ..                                                 ...     ...
# 695  All the leaves are brown\nAnd the sky is grey\...       2
# 696  I've been fuckin' hoes and poppin' pillies\nMa...       0
# 697  Одинокий прекрасный\nВ синем небе парил\nПрола...       2
# 698  Вновь проснулся бодреньким, так что знай: я в ...       0
# 699  Tides thrash inside, baby, I'm high octane\nFe...       4
#
# [700 rows x 21 columns]

# %%
# using random forest classifier to evaluate the most important features in determining the kmeans clusters
from sklearn.ensemble import RandomForestClassifier

X_train = df.drop(columns=['Cluster'])
y_train = df['Cluster']

transformer = make_column_transformer(
    (StandardScaler(), ['mode', 'key', 'valence', 'tempo', 'time_signature', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness']),
    (TfidfVectorizer(max_features = 1000), 'lyrics')
)

model = RandomForestClassifier(n_estimators=100, random_state=42)

pipeline = Pipeline([
    ('transform', transformer),
    ('cluster', model)
])

pipeline.fit(X_train, y_train)

trained_model = pipeline.named_steps['cluster']

importances = trained_model.feature_importances_

transformed_features = pipeline.named_steps['transform'].get_feature_names_out()

feature_importances = pd.DataFrame({'Feature': transformed_features, 'Importance': importances})
feature_importances = feature_importances.sort_values('Importance', ascending=False)

feature_importances.head(50)
# Out:
#                               Feature  Importance
# 0                standardscaler__mode    0.124084
# 6              standardscaler__energy    0.046399
# 7            standardscaler__loudness    0.041085
# 5        standardscaler__danceability    0.028495
# 8         standardscaler__speechiness    0.023112
# 9        standardscaler__acousticness    0.019014
# 10   standardscaler__instrumentalness    0.015624
# 2             standardscaler__valence    0.010848
# 4      standardscaler__time_signature    0.009732
# 11           standardscaler__liveness    0.008054
# 528               tfidfvectorizer__me    0.007007
# 3               standardscaler__tempo    0.006706
# 1                 standardscaler__key    0.006598
# 839              tfidfvectorizer__the    0.005761
# 682               tfidfvectorizer__re    0.005119
# 994              tfidfvectorizer__you    0.004994
# 302              tfidfvectorizer__for    0.004924
# 838             tfidfvectorizer__that    0.004793
# 613               tfidfvectorizer__on    0.004766
# 428               tfidfvectorizer__in    0.004271
# 434               tfidfvectorizer__it    0.004254
# 873               tfidfvectorizer__to    0.004248
# 933             tfidfvectorizer__want    0.004073
# 25               tfidfvectorizer__all    0.003997
# 576               tfidfvectorizer__my    0.003922
# 33               tfidfvectorizer__and    0.003886
# 610               tfidfvectorizer__oh    0.003876
# 845             tfidfvectorizer__they    0.003789
# 359            tfidfvectorizer__gucci    0.003743
# 943               tfidfvectorizer__we    0.003717
# 967             tfidfvectorizer__with    0.003703
# 479             tfidfvectorizer__like    0.003662
# 988             tfidfvectorizer__yeah    0.003536
# 766               tfidfvectorizer__so    0.003519
# 130              tfidfvectorizer__but    0.003512
# 597               tfidfvectorizer__no    0.003469
# 950             tfidfvectorizer__what    0.003443
# 328              tfidfvectorizer__get    0.003411
# 456             tfidfvectorizer__know    0.003406
# 608               tfidfvectorizer__of    0.003344
# 501             tfidfvectorizer__love    0.003323
# 220              tfidfvectorizer__don    0.003239
# 912               tfidfvectorizer__up    0.003197
# 867             tfidfvectorizer__time    0.003185
# 441             tfidfvectorizer__just    0.003180
# 996             tfidfvectorizer__your    0.003113
# 394              tfidfvectorizer__her    0.003064
# 350              tfidfvectorizer__got    0.002969
# 66                tfidfvectorizer__be    0.002913
# 843            tfidfvectorizer__there    0.002861

# %%
# using a tsne to evaluate the quality of our clusters and how distinct they are
from sklearn.manifold import TSNE

transformer = make_column_transformer(
    (StandardScaler(), ['mode', 'key', 'valence', 'tempo', 'time_signature', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness']),
)

transformed = transformer.fit_transform(X_train)
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_tsne = tsne.fit_transform(transformed) # note: did not include lyrics bc the tsne transform doesn't allow for a sparse matrix

df['Cluster'] = df['Cluster'].astype(int)
df['Cluster'] = df['Cluster'].replace(cluster_labels)
df['Cluster'] = df['Cluster'].astype(str).str.strip()

sorted_clusters = [
    'High-Energy Dance Music',
    'Indie & Electronic',
    'Nostalgic Pop',
    'Rap & Viral Memes',
    'Heartbreak & Emotional Songs'
]

custom_colors = {
    'High-Energy Dance Music': '#93179c',
    'Indie & Electronic': '#802ebf',
    'Nostalgic Pop': '#5244d4',
    'Rap & Viral Memes': '#769ee3',
    'Heartbreak & Emotional Songs': '#c2ddf2'
}

fig = px.scatter(x=X_tsne[:, 0], y=X_tsne[:, 1], color=df['Cluster'],
                 category_orders={"Cluster": sorted_clusters},
                 color_discrete_map=custom_colors,
                 title="TSNE Projection of K-Means Clusters",)
fig.update_traces(marker=dict(size=10, line=dict(width=1, color="white")))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7621dbd4-b52e-4df8-bb0b-327f6d87a44f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7621dbd4-b52e-4df8-bb0b-327f6d87a44f")) {                    Plotly.newPlot(                        "7621dbd4-b52e-4df8-bb0b-327f6d87a44f",                        [{"hovertemplate":"color=High-Energy Dance Music\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High-Energy Dance Music","marker":{"color":"#93179c","symbol":"circle","line":{"color":"white","width":1},"size":10},"mode":"markers","name":"High-Energy Dance Music","orientation":"v","showlegend":true,"x":[6.9931445,-3.527742,-13.635185,-14.721452,7.0733867,-8.401858,-1.3050859,-9.85626,-2.6701682,-18.582245,-11.365969,6.327141,-4.619859,-10.559708,-10.910558,-9.635694,7.7369537,-13.289279,-3.6360602,-13.21998,7.1598635,-21.15425,-15.802704,-8.784259,3.832794,4.269502,-3.2964416,-17.698769,4.394919,-9.849367,-5.6552353,-16.415916,2.0430984,-19.663637,-2.7163334,-19.104818,-10.963281,6.1172323,-13.73238,-18.304554,-17.303879,-9.497409,-13.267867,-2.6170115,-7.971985,-15.503121,-5.3895574,-14.280078,1.8184404,-14.622205,-14.970733,-8.543319,18.70113,-17.796835,-14.274534,-0.36039317,-17.183092,-11.603539,4.9268336,-1.1304914,-14.55628,11.526749,-20.724897,-5.215341,-3.681765,-4.048276,-1.0038482,-15.761791,4.08579,1.9973462,-7.281632,4.167159,1.1700723,12.303851,-15.91283,3.5158749,-13.342712,-3.9926672,-12.612956,-6.988027,-6.017323,-2.2080905,-0.3328107,-20.910376,-29.949978,-17.142223,5.786587,-11.091249,3.5527308,-14.376826,3.241416,-19.453686,-9.81827,6.3626933,1.4277102,-0.8934817,-2.300164,-7.670644,10.685399,-11.669208,-16.870443,-11.434133,-0.9726707,-4.427357,-1.3699567,-3.5207586,-4.9403815,1.6515927,-3.6890516,5.9290366,-0.27024752,-7.28367,-4.2926626,-6.273689,5.5062547,5.1411014,1.4836308,-3.6002464,8.460106,-1.4991744,1.0838376,-20.991291,-15.542297,-0.6507129,-11.884748,-1.1523622,-17.005014,-16.055555,-2.9988837,4.2269807,-2.2772512,-0.48192412,-9.081386,-16.528763,-6.556931,7.8436832,-13.236939,-8.344804,5.678072,-18.241756,-3.9410708,4.194501,-19.639343,-2.0485039,18.924255,-14.156585,-17.587666,-0.22601016,-5.822607,-13.062413,-6.080708,-2.7677164,-11.602662,4.0282893,-1.7234353,-16.517532,-14.249139,-8.91819,-1.7196555,-0.11526172,18.191393,-16.820005,-8.928101,3.434126,1.7829137,4.8619227,-29.683636,-8.43981,-12.635007,-7.360248,-13.649516,-5.5576243,11.907125,-13.040711,-18.63425,-13.683027,-7.638758,-17.208284,-16.09584,-10.177243,-13.879366,-4.4825525,-15.364372,-17.753288,2.1058125,-14.2685175,-14.010697,-17.142225,-11.534475,5.5549827,-8.3907995,7.7386045,-7.682102,3.3062127,-12.432461,-17.077864,6.6502748,0.7721626,1.7876457,-2.9203796,3.5519626,5.1720886,-17.484825,5.844829,-18.026516,2.775815,0.5923967,3.9588587,-16.03816,-11.924577,-7.6459937,-14.557143,-8.947374,-12.59006,-5.8769274,-19.550247,-12.34866,8.725754,0.5866206,9.038578,0.118401356,-7.044685,-7.6938505,-0.86098546,-19.964054,4.6495957,4.0527472,9.135779,2.023419,-19.158396,-16.49505,-4.2146072,-14.773731,-15.4161415,1.9495298,4.4918756,-8.10989,-5.626937,-1.8722744,-7.050029,-16.957361,-5.116197,10.409127,8.36522,-8.169615,-11.936398,-9.702993,-14.810024,-11.929349,0.83098423,1.7206429,4.1050158,-21.387688,-20.298977,-16.636208,10.016447,-15.801176,-11.164529,8.559853,-16.926926,-29.676321,-7.931921,-7.2927246,-6.5067277,-7.616034,-11.001136,3.9770098,-10.196672,-10.434094,-18.486683,2.5797184],"xaxis":"x","y":[-20.838581,-13.7651415,-15.722968,-17.107073,-21.309309,-5.849241,-19.233345,-4.8908653,-33.3557,4.681268,-21.959017,-14.94854,-20.2684,-18.634243,-3.7899456,-16.81637,-16.763071,-21.524664,-29.648254,0.2912492,-29.383053,4.6476865,- ...
